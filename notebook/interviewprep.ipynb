# %% [markdown]
# ## Interview prep for data analysis using python

# %%
import pandas as pd
import numpy as np

# %%
nba = pd.read_csv("data/nba.csv")

# %%
nba.head(5)
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
nba.describe()
# Out:
#            Number         Age      Weight        Salary
# count  457.000000  457.000000  457.000000  4.460000e+02
# mean    17.678337   26.938731  221.522976  4.842684e+06
# std     15.966090    4.404016   26.368343  5.229238e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.044792e+06
# 50%     13.000000   26.000000  220.000000  2.839073e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
nba.shape
# Out:
# (458, 9)

# %%
# Select One Column from a DataFrame
nba.Name
# type(nba.Name)
# Out:
# pandas.core.series.Series

# %%
nba['Name']
# type(nba['Name'])
# Out:
# pandas.core.series.Series

# %%
# Select Two or More Columns from a DataFrame
nba[['Name', 'Team', 'Age']]
# type(nba[['Name', 'Team', 'Age']])
# Out:
#               Name            Team   Age
# 0    Avery Bradley  Boston Celtics  25.0
# 1      Jae Crowder  Boston Celtics  25.0
# 2     John Holland  Boston Celtics  27.0
# 3      R.J. Hunter  Boston Celtics  22.0
# 4    Jonas Jerebko  Boston Celtics  29.0
# ..             ...             ...   ...
# 453   Shelvin Mack       Utah Jazz  26.0
# 454      Raul Neto       Utah Jazz  24.0
# 455   Tibor Pleiss       Utah Jazz  26.0
# 456    Jeff Withey       Utah Jazz  26.0
# 457            NaN             NaN   NaN
#
# [458 rows x 3 columns]

# %%
new_cols = ['Name', 'Team', 'Age']
nba[new_cols]
# Out:
#               Name            Team   Age
# 0    Avery Bradley  Boston Celtics  25.0
# 1      Jae Crowder  Boston Celtics  25.0
# 2     John Holland  Boston Celtics  27.0
# 3      R.J. Hunter  Boston Celtics  22.0
# 4    Jonas Jerebko  Boston Celtics  29.0
# ..             ...             ...   ...
# 453   Shelvin Mack       Utah Jazz  26.0
# 454      Raul Neto       Utah Jazz  24.0
# 455   Tibor Pleiss       Utah Jazz  26.0
# 456    Jeff Withey       Utah Jazz  26.0
# 457            NaN             NaN   NaN
#
# [458 rows x 3 columns]

# %%
# Add New Column to DataFrame
nba['Sport'] = 'Basketball'

# %%
nba.head()
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
#
#              College     Salary       Sport
# 0              Texas  7730337.0  Basketball
# 1          Marquette  6796117.0  Basketball
# 2  Boston University        NaN  Basketball
# 3      Georgia State  1148640.0  Basketball
# 4                NaN  5000000.0  Basketball

# %%
# Add New Column to DataFrame at specific location
nba.insert(loc = 3, column = "League", value = "NBA")
nba.head()
# Out:
#             Name            Team  Number League Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0    NBA       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0    NBA       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0    NBA       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0    NBA       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0    NBA       PF  29.0   6-10   231.0
#
#              College     Salary       Sport
# 0              Texas  7730337.0  Basketball
# 1          Marquette  6796117.0  Basketball
# 2  Boston University        NaN  Basketball
# 3      Georgia State  1148640.0  Basketball
# 4                NaN  5000000.0  Basketball

# %%
# Create New Column from Existing Column
new_age_list = nba['Age'] + 10
nba.insert(loc = 6, column = "Age in a Decade", value = new_age_list)
nba.head()
# Out:
#             Name            Team  Number League Position   Age  \
# 0  Avery Bradley  Boston Celtics     0.0    NBA       PG  25.0
# 1    Jae Crowder  Boston Celtics    99.0    NBA       SF  25.0
# 2   John Holland  Boston Celtics    30.0    NBA       SG  27.0
# 3    R.J. Hunter  Boston Celtics    28.0    NBA       SG  22.0
# 4  Jonas Jerebko  Boston Celtics     8.0    NBA       PF  29.0
#
#    Age in a Decade Height  Weight            College     Salary       Sport
# 0             35.0    6-2   180.0              Texas  7730337.0  Basketball
# 1             35.0    6-6   235.0          Marquette  6796117.0  Basketball
# 2             37.0    6-5   205.0  Boston University        NaN  Basketball
# 3             32.0    6-5   185.0      Georgia State  1148640.0  Basketball
# 4             39.0   6-10   231.0                NaN  5000000.0  Basketball

# %%
# value_counts()
nba['Team'].value_counts().head()
# Out:
# New Orleans Pelicans    19
# Memphis Grizzlies       18
# Milwaukee Bucks         16
# New York Knicks         16
# Los Angeles Lakers      15
# Name: Team, dtype: int64

# %%
# Drop DataFrame Rows with Null Values with the dropna Method
nba.isnull()
# Out:
#       Name   Team  Number  League  Position    Age  Age in a Decade  Height  \
# 0    False  False   False   False     False  False            False   False
# 1    False  False   False   False     False  False            False   False
# 2    False  False   False   False     False  False            False   False
# 3    False  False   False   False     False  False            False   False
# 4    False  False   False   False     False  False            False   False
# ..     ...    ...     ...     ...       ...    ...              ...     ...
# 453  False  False   False   False     False  False            False   False
# 454  False  False   False   False     False  False            False   False
# 455  False  False   False   False     False  False            False   False
# 456  False  False   False   False     False  False            False   False
# 457   True   True    True   False      True   True             True    True
#
#      Weight  College  Salary  Sport
# ...

# %%
nba.isnull().sum()
# Out:
# Name                1
# Team                1
# Number              1
# League              0
# Position            1
# Age                 1
# Age in a Decade     1
# Height              1
# Weight              1
# College            85
# Salary             12
# Sport               0
# dtype: int64

# %%
a = nba.dropna(how='any')

# %%
a.isnull().sum()
# Out:
# Name               0
# Team               0
# Number             0
# League             0
# Position           0
# Age                0
# Age in a Decade    0
# Height             0
# Weight             0
# College            0
# Salary             0
# Sport              0
# dtype: int64

# %%
nba.dropna(subset=['College'])
# Out:
#               Name            Team  Number League Position   Age  \
# 0    Avery Bradley  Boston Celtics     0.0    NBA       PG  25.0
# 1      Jae Crowder  Boston Celtics    99.0    NBA       SF  25.0
# 2     John Holland  Boston Celtics    30.0    NBA       SG  27.0
# 3      R.J. Hunter  Boston Celtics    28.0    NBA       SG  22.0
# 6    Jordan Mickey  Boston Celtics    55.0    NBA       PF  21.0
# ..             ...             ...     ...    ...      ...   ...
# 449    Rodney Hood       Utah Jazz     5.0    NBA       SG  23.0
# 451  Chris Johnson       Utah Jazz    23.0    NBA       SF  26.0
# 452     Trey Lyles       Utah Jazz    41.0    NBA       PF  20.0
# 453   Shelvin Mack       Utah Jazz     8.0    NBA       PG  26.0
# 456    Jeff Withey       Utah Jazz    24.0    NBA        C  26.0
#
#      Age in a Decade Height  Weight            College     Salary       Sport
# 0               35.0    6-2   180.0              Texas  7730337.0  Basketball
# ...

# %%
# Fill in Missing DataFrame Values with the fillna Method
nba.tail()
# Out:
#              Name       Team  Number League Position   Age  Age in a Decade  \
# 453  Shelvin Mack  Utah Jazz     8.0    NBA       PG  26.0             36.0
# 454     Raul Neto  Utah Jazz    25.0    NBA       PG  24.0             34.0
# 455  Tibor Pleiss  Utah Jazz    21.0    NBA        C  26.0             36.0
# 456   Jeff Withey  Utah Jazz    24.0    NBA        C  26.0             36.0
# 457           NaN        NaN     NaN    NBA      NaN   NaN              NaN
#
#     Height  Weight College     Salary       Sport
# 453    6-3   203.0  Butler  2433333.0  Basketball
# 454    6-1   179.0     NaN   900000.0  Basketball
# 455    7-3   256.0     NaN  2900000.0  Basketball
# 456    7-0   231.0  Kansas   947276.0  Basketball
# 457    NaN     NaN     NaN        NaN  Basketball

# %%
nba.fillna(0).tail()
# Out:
#              Name       Team  Number League Position   Age  Age in a Decade  \
# 453  Shelvin Mack  Utah Jazz     8.0    NBA       PG  26.0             36.0
# 454     Raul Neto  Utah Jazz    25.0    NBA       PG  24.0             34.0
# 455  Tibor Pleiss  Utah Jazz    21.0    NBA        C  26.0             36.0
# 456   Jeff Withey  Utah Jazz    24.0    NBA        C  26.0             36.0
# 457             0          0     0.0    NBA        0   0.0              0.0
#
#     Height  Weight College     Salary       Sport
# 453    6-3   203.0  Butler  2433333.0  Basketball
# 454    6-1   179.0       0   900000.0  Basketball
# 455    7-3   256.0       0  2900000.0  Basketball
# 456    7-0   231.0  Kansas   947276.0  Basketball
# 457      0     0.0       0        0.0  Basketball

# %%
nba.tail()
# Out:
#              Name       Team  Number League Position   Age  Age in a Decade  \
# 453  Shelvin Mack  Utah Jazz     8.0    NBA       PG  26.0             36.0
# 454     Raul Neto  Utah Jazz    25.0    NBA       PG  24.0             34.0
# 455  Tibor Pleiss  Utah Jazz    21.0    NBA        C  26.0             36.0
# 456   Jeff Withey  Utah Jazz    24.0    NBA        C  26.0             36.0
# 457           NaN        NaN     NaN    NBA      NaN   NaN              NaN
#
#     Height  Weight College     Salary       Sport
# 453    6-3   203.0  Butler  2433333.0  Basketball
# 454    6-1   179.0     NaN   900000.0  Basketball
# 455    7-3   256.0     NaN  2900000.0  Basketball
# 456    7-0   231.0  Kansas   947276.0  Basketball
# 457    NaN     NaN     NaN        NaN  Basketball

# %%
nba['College'].fillna('Unknown')
# Out:
# 0                  Texas
# 1              Marquette
# 2      Boston University
# 3          Georgia State
# 4                Unknown
#              ...
# 453               Butler
# 454              Unknown
# 455              Unknown
# 456               Kansas
# 457              Unknown
# Name: College, Length: 458, dtype: object

# %%
nba['College'].fillna('Unknown', inplace = True)

# %%
nba.tail()
# Out:
#              Name       Team  Number League Position   Age  Age in a Decade  \
# 453  Shelvin Mack  Utah Jazz     8.0    NBA       PG  26.0             36.0
# 454     Raul Neto  Utah Jazz    25.0    NBA       PG  24.0             34.0
# 455  Tibor Pleiss  Utah Jazz    21.0    NBA        C  26.0             36.0
# 456   Jeff Withey  Utah Jazz    24.0    NBA        C  26.0             36.0
# 457           NaN        NaN     NaN    NBA      NaN   NaN              NaN
#
#     Height  Weight  College     Salary       Sport
# 453    6-3   203.0   Butler  2433333.0  Basketball
# 454    6-1   179.0  Unknown   900000.0  Basketball
# 455    7-3   256.0  Unknown  2900000.0  Basketball
# 456    7-0   231.0   Kansas   947276.0  Basketball
# 457    NaN     NaN  Unknown        NaN  Basketball

# %%
# The astype Method I
# type(nba['Age'])
# nba['Age'].hasnans
nba1 = nba.copy()
nba1.dropna(how='any', inplace=True)

# %%
nba1['Age'].hasnans
# Out:
# False

# %%
nba1.tail()
# Out:
#              Name       Team  Number League Position   Age  Age in a Decade  \
# 452    Trey Lyles  Utah Jazz    41.0    NBA       PF  20.0             30.0
# 453  Shelvin Mack  Utah Jazz     8.0    NBA       PG  26.0             36.0
# 454     Raul Neto  Utah Jazz    25.0    NBA       PG  24.0             34.0
# 455  Tibor Pleiss  Utah Jazz    21.0    NBA        C  26.0             36.0
# 456   Jeff Withey  Utah Jazz    24.0    NBA        C  26.0             36.0
#
#     Height  Weight   College     Salary       Sport
# 452   6-10   234.0  Kentucky  2239800.0  Basketball
# 453    6-3   203.0    Butler  2433333.0  Basketball
# 454    6-1   179.0   Unknown   900000.0  Basketball
# 455    7-3   256.0   Unknown  2900000.0  Basketball
# 456    7-0   231.0    Kansas   947276.0  Basketball

# %%
nba1['Age'] = nba1['Age'].astype('int')
nba1.tail()
# Out:
#              Name       Team  Number League Position  Age  Age in a Decade  \
# 452    Trey Lyles  Utah Jazz    41.0    NBA       PF   20             30.0
# 453  Shelvin Mack  Utah Jazz     8.0    NBA       PG   26             36.0
# 454     Raul Neto  Utah Jazz    25.0    NBA       PG   24             34.0
# 455  Tibor Pleiss  Utah Jazz    21.0    NBA        C   26             36.0
# 456   Jeff Withey  Utah Jazz    24.0    NBA        C   26             36.0
#
#     Height  Weight   College     Salary       Sport
# 452   6-10   234.0  Kentucky  2239800.0  Basketball
# 453    6-3   203.0    Butler  2433333.0  Basketball
# 454    6-1   179.0   Unknown   900000.0  Basketball
# 455    7-3   256.0   Unknown  2900000.0  Basketball
# 456    7-0   231.0    Kansas   947276.0  Basketball

# %%
nba['Position'].unique()
# Out:
# array(['PG', 'SF', 'SG', 'PF', 'C', nan], dtype=object)

# %%
nba['Position'].nunique()
# Out:
# 5

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             457 non-null    object
#  1   Team             457 non-null    object
#  2   Number           457 non-null    float64
#  3   League           458 non-null    object
#  4   Position         457 non-null    object
#  5   Age              457 non-null    float64
#  6   Age in a Decade  457 non-null    float64
#  7   Height           457 non-null    object
#  8   Weight           457 non-null    float64
#  9   College          458 non-null    object
#  10  Salary           446 non-null    float64
#  11  Sport            458 non-null    object
# dtypes: float64(5), object(7)
# memory usage: 43.1+ KB

# %%
nba['Position'] = nba['Position'].astype('category')

# %%
nba.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             457 non-null    object
#  1   Team             457 non-null    object
#  2   Number           457 non-null    float64
#  3   League           458 non-null    object
#  4   Position         457 non-null    category
#  5   Age              457 non-null    float64
#  6   Age in a Decade  457 non-null    float64
#  7   Height           457 non-null    object
#  8   Weight           457 non-null    float64
#  9   College          458 non-null    object
#  10  Salary           446 non-null    float64
#  11  Sport            458 non-null    object
# dtypes: category(1), float64(5), object(6)
# memory usage: 40.1+ KB

# %%
# Sort a DataFrame with the sort_values Method, Part I
nba['Salary'].sort_values()
# Out:
# 32      30888.0
# 291     55722.0
# 130     55722.0
# 135     83397.0
# 175    111196.0
#          ...
# 350         NaN
# 353         NaN
# 397         NaN
# 409         NaN
# 457         NaN
# Name: Salary, Length: 458, dtype: float64

# %%
nba.sort_values(by = 'Salary', na_position = 'first')
# Out:
#                 Name                 Team  Number League Position   Age  \
# 2       John Holland       Boston Celtics    30.0    NBA       SG  27.0
# 46       Elton Brand   Philadelphia 76ers    42.0    NBA       PF  37.0
# 171    Dahntay Jones  Cleveland Cavaliers    30.0    NBA       SG  35.0
# 264    Jordan Farmar    Memphis Grizzlies     4.0    NBA       PG  29.0
# 269     Ray McCallum    Memphis Grizzlies     5.0    NBA       PG  24.0
# ..               ...                  ...     ...    ...      ...   ...
# 339       Chris Bosh           Miami Heat     1.0    NBA       PF  32.0
# 251    Dwight Howard      Houston Rockets    12.0    NBA        C  30.0
# 33   Carmelo Anthony      New York Knicks     7.0    NBA       SF  32.0
# 169     LeBron James  Cleveland Cavaliers    23.0    NBA       SF  31.0
# 109      Kobe Bryant   Los Angeles Lakers    24.0    NBA       SF  37.0
#
#      Age in a Decade Height  Weight            College      Salary       Sport
# ...

# %%
nba.sort_values(by = ['Team', 'Name'])
# Out:
#                 Name                Team  Number League Position   Age  \
# 312       Al Horford       Atlanta Hawks    15.0    NBA        C  30.0
# 318  Dennis Schroder       Atlanta Hawks    17.0    NBA       PG  22.0
# 323      Jeff Teague       Atlanta Hawks     0.0    NBA       PG  27.0
# 309    Kent Bazemore       Atlanta Hawks    24.0    NBA       SF  26.0
# 311     Kirk Hinrich       Atlanta Hawks    12.0    NBA       SG  35.0
# ..               ...                 ...     ...    ...      ...   ...
# 376  Markieff Morris  Washington Wizards     5.0    NBA       PF  26.0
# 375     Nene Hilario  Washington Wizards    42.0    NBA        C  33.0
# 378  Otto Porter Jr.  Washington Wizards    22.0    NBA       SF  23.0
# 379   Ramon Sessions  Washington Wizards     7.0    NBA       PG  30.0
# 457              NaN                 NaN     NaN    NBA      NaN   NaN
#
#      Age in a Decade Height  Weight       College      Salary       Sport
# ...

# %%
nba.sort_values(by = ['Team', 'Name'], ascending = [True, False])
# Out:
#                  Name                Team  Number League Position   Age  \
# 322    Walter Tavares       Atlanta Hawks    22.0    NBA        C  24.0
# 310  Tim Hardaway Jr.       Atlanta Hawks    10.0    NBA       SG  24.0
# 321    Tiago Splitter       Atlanta Hawks    11.0    NBA        C  31.0
# 320   Thabo Sefolosha       Atlanta Hawks    25.0    NBA       SF  32.0
# 315      Paul Millsap       Atlanta Hawks     4.0    NBA       PF  31.0
# ..                ...                 ...     ...    ...      ...   ...
# 380    Garrett Temple  Washington Wizards    17.0    NBA       SG  30.0
# 372       Drew Gooden  Washington Wizards    90.0    NBA       PF  34.0
# 369      Bradley Beal  Washington Wizards     3.0    NBA       SG  22.0
# 368     Alan Anderson  Washington Wizards     6.0    NBA       SG  33.0
# 457               NaN                 NaN     NaN    NBA      NaN   NaN
#
#      Age in a Decade Height  Weight         College      Salary       Sport
# ...

# %%
# Sort DataFrame Index with the sort_index Method
nba.sort_index(ascending = False)
# Out:
#               Name            Team  Number League Position   Age  \
# 457            NaN             NaN     NaN    NBA      NaN   NaN
# 456    Jeff Withey       Utah Jazz    24.0    NBA        C  26.0
# 455   Tibor Pleiss       Utah Jazz    21.0    NBA        C  26.0
# 454      Raul Neto       Utah Jazz    25.0    NBA       PG  24.0
# 453   Shelvin Mack       Utah Jazz     8.0    NBA       PG  26.0
# ..             ...             ...     ...    ...      ...   ...
# 4    Jonas Jerebko  Boston Celtics     8.0    NBA       PF  29.0
# 3      R.J. Hunter  Boston Celtics    28.0    NBA       SG  22.0
# 2     John Holland  Boston Celtics    30.0    NBA       SG  27.0
# 1      Jae Crowder  Boston Celtics    99.0    NBA       SF  25.0
# 0    Avery Bradley  Boston Celtics     0.0    NBA       PG  25.0
#
#      Age in a Decade Height  Weight            College     Salary       Sport
# 457              NaN    NaN     NaN            Unknown        NaN  Basketball
# ...

# %%
# Rank Series Values with the rank Method
# nba
nba['Salary'] = nba['Salary'].fillna(0).astype('int')
nba.sort_values(by = 'Salary', ascending = False)
# Out:
#                 Name                    Team  Number Position   Age Height  \
# 109      Kobe Bryant      Los Angeles Lakers    24.0       SF  37.0    6-6
# 169     LeBron James     Cleveland Cavaliers    23.0       SF  31.0    6-8
# 33   Carmelo Anthony         New York Knicks     7.0       SF  32.0    6-8
# 251    Dwight Howard         Houston Rockets    12.0        C  30.0   6-11
# 339       Chris Bosh              Miami Heat     1.0       PF  32.0   6-11
# ..               ...                     ...     ...      ...   ...    ...
# 269     Ray McCallum       Memphis Grizzlies     5.0       PG  24.0    6-3
# 409       Greg Smith  Minnesota Timberwolves     4.0       PF  25.0   6-10
# 2       John Holland          Boston Celtics    30.0       SG  27.0    6-5
# 264    Jordan Farmar       Memphis Grizzlies     4.0       PG  29.0    6-2
# 457              NaN                     NaN     NaN      NaN   NaN    NaN
#
#      Weight            College    Salary
# ...

# %%
nba = nba.dropna(how='all')
nba['Salary'] = nba['Salary'].fillna(0).astype('int')
nba
# nba['Salary'].rank()
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College   Salary
# 0                Texas  7730337
# ...

# %%
nba['Salary'].rank(ascending = False).astype('int')
# Out:
# 0       97
# 1      110
# 2      452
# 3      322
# 4      147
#       ...
# 453    241
# 454    383
# 455    214
# 456    367
# 457    452
# Name: Salary, Length: 458, dtype: int64

# %%
nba['Salary Rank'] = nba['Salary'].rank(ascending = False).astype('int')
nba
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College   Salary  Salary Rank
# 0                Texas  7730337           97
# ...

# %%
nba.sort_values("Salary", ascending=False)
# Out:
#                 Name                    Team  Number Position   Age Height  \
# 109      Kobe Bryant      Los Angeles Lakers    24.0       SF  37.0    6-6
# 169     LeBron James     Cleveland Cavaliers    23.0       SF  31.0    6-8
# 33   Carmelo Anthony         New York Knicks     7.0       SF  32.0    6-8
# 251    Dwight Howard         Houston Rockets    12.0        C  30.0   6-11
# 339       Chris Bosh              Miami Heat     1.0       PF  32.0   6-11
# ..               ...                     ...     ...      ...   ...    ...
# 269     Ray McCallum       Memphis Grizzlies     5.0       PG  24.0    6-3
# 409       Greg Smith  Minnesota Timberwolves     4.0       PF  25.0   6-10
# 2       John Holland          Boston Celtics    30.0       SG  27.0    6-5
# 264    Jordan Farmar       Memphis Grizzlies     4.0       PG  29.0    6-2
# 457              NaN                     NaN     NaN      NaN   NaN    NaN
#
#      Weight            College    Salary  Salary Rank
# ...
